# %% [markdown]
# <a href="https://colab.research.google.com/github/18K41A0565/ASSIGNMENT-III/blob/master/ASSIGNMENT-III.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
mpd=pd.read_csv('mobile_cleaned-1549119762886.csv')

# %%
mpd.describe()
# Out:
#          sim_type    aperture  ...  processor_rank    is_liked
# count  109.000000  109.000000  ...      109.000000  109.000000
# mean     0.981651    7.733945  ...       50.788991    0.844037
# std      1.347025    3.201973  ...       49.496366    0.364496
# min      0.000000    0.000000  ...        1.000000    0.000000
# 25%      0.000000    8.000000  ...       12.000000    1.000000
# 50%      0.000000    8.000000  ...       21.000000    1.000000
# 75%      3.000000   10.000000  ...       92.000000    1.000000
# max      4.000000   14.000000  ...      166.000000    1.000000
#
# [8 rows x 40 columns]

# %%
mpd.isnull()
# Out:
#      sim_type  aperture  gpu_rank  ...  battery_capacity  processor_rank  is_liked
# 0       False     False     False  ...             False           False     False
# 1       False     False     False  ...             False           False     False
# 2       False     False     False  ...             False           False     False
# 3       False     False     False  ...             False           False     False
# 4       False     False     False  ...             False           False     False
# ..        ...       ...       ...  ...               ...             ...       ...
# 104     False     False     False  ...             False           False     False
# 105     False     False     False  ...             False           False     False
# 106     False     False     False  ...             False           False     False
# 107     False     False     False  ...             False           False     False
# ...

# %%
mpd.isnull().sum()
# Out:
# sim_type                             0
# aperture                             0
# gpu_rank                             0
# weight                               1
# stand_by_time                        3
# processor_frequency                  0
# thickness                            0
# flash_type                           0
# front_camera_resolution              0
# auto_focus                           0
# screen_size                          0
# frames_per_second                    0
# FM                                   0
# no_of_reviews_in_gsmarena_in_week    2
# os                                   0
# phone_height                         1
# screen_protection                    0
# sim_size                             0
# price                                0
# talk_time                            1
# video_resolution                     1
# display_resolution                   0
# removable_battery                    0
# display_type                         0
# ...

# %%
mpd['weight']=mpd['weight'].fillna(mpd['weight'].mean())
mpd['primary_camera_resolution']=mpd['primary_camera_resolution'].fillna(mpd['primary_camera_resolution'].mean())
mpd['front_camera_resolution']=mpd['front_camera_resolution'].fillna(mpd['front_camera_resolution'].mean())
mpd['talk_time']=mpd['talk_time'].fillna(mpd['talk_time'].mean())
mpd['phone_height']=mpd['phone_height'].fillna(mpd['phone_height'].mean())
mpd['no_of_reviews_in_gsmarena_in_week']=mpd['no_of_reviews_in_gsmarena_in_week'].fillna(mpd['no_of_reviews_in_gsmarena_in_week'].mean())
mpd['stand_by_time']=mpd['stand_by_time'].fillna(mpd['stand_by_time'].mean())
mpd['video_resolution']=mpd['video_resolution'].fillna(mpd['video_resolution'].mean())

# %%
mpd.isnull().sum()
# Out:
# sim_type                             0
# aperture                             0
# gpu_rank                             0
# weight                               0
# stand_by_time                        0
# processor_frequency                  0
# thickness                            0
# flash_type                           0
# front_camera_resolution              0
# auto_focus                           0
# screen_size                          0
# frames_per_second                    0
# FM                                   0
# no_of_reviews_in_gsmarena_in_week    0
# os                                   0
# phone_height                         0
# screen_protection                    0
# sim_size                             0
# price                                0
# talk_time                            0
# video_resolution                     0
# display_resolution                   0
# removable_battery                    0
# display_type                         0
# ...

# %% [markdown]
# 2.Draw correlation graph for mobile price with all attributes.

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,0:1]
plt.xlabel("price")
plt.ylabel("sim_type")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,1:2]
plt.xlabel("price")
plt.ylabel("aperture")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,2:3]
plt.xlabel("price")
plt.ylabel("gpu_rank")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,5:6]
plt.xlabel("price")
plt.ylabel("processor_frequency")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,6:7]
plt.xlabel("price")
plt.ylabel("thickness")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,7:8]
plt.xlabel("price")
plt.ylabel("flash_type")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,8:9]
plt.xlabel("price")
plt.ylabel("front_camera_resolution")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,25:26]
plt.xlabel("price")
plt.ylabel("battery_type")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,26:27]
plt.xlabel("price")
plt.ylabel("ram_memory")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,27:28]
plt.xlabel("price")
plt.ylabel("internal_memory")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,28:29]
plt.xlabel("price")
plt.ylabel("brand_rank")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,29:30]
plt.xlabel("price")
plt.ylabel("no_of_cores")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,30:31]
plt.xlabel("price")
plt.ylabel("micro_sd_slot")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,31:32]
plt.xlabel("price")
plt.ylabel("screen_pixel_density")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,32:33]
plt.xlabel("price")
plt.ylabel("water_proof_rate")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,33:34]
plt.xlabel("price")
plt.ylabel("phone_width")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
 
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,34:35]
plt.xlabel("price")
plt.ylabel("expandable_memory")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,39:40]
plt.xlabel("price")
plt.ylabel("is_linked")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %% [markdown]
# 3.Compute outer product of 2 vectors. Eg:
#
# original matrix: [[1, 0], [0, 1]] [[1, 2], [3, 4]] Outer product of the said two vectors: [[1 2 3 4] [0 0 0 0] [0 0 0 0] [1 2 3 4]]

# %%
import numpy as s
p=[[1,0],[0,1]]
q=[[1,2],[3,4]]
print("ORIGINAL MATRIX IS:")
print(p)
print(q)
print("THE OUTER PRODUCT OF GIVEN VECTORS IS :  \n",s.outer(p,q))
# Out:
# ORIGINAL MATRIX IS:
# [[1, 0], [0, 1]]
# [[1, 2], [3, 4]]
# THE OUTER PRODUCT OF GIVEN VECTORS IS :
#  [[1 2 3 4]
#  [0 0 0 0]
#  [0 0 0 0]
#  [1 2 3 4]]

# %% [markdown]
# 4.Write a NumPy program to compute the condition number of a given matrix. Original matrix: [[1 2] [3 4]] Condition number of the said matrix: 14.9330343737

# %%
import numpy as np
m = np.array([[1,2],[3,4]])
print("Original matrix:")
print(m)
result =  np.linalg.cond(m)
print("Condition number of the said matrix:")
print(result)
# Out:
# Original matrix:
# [[1 2]
#  [3 4]]
# Condition number of the said matrix:
# 14.933034373659268

# %% [markdown]
# 5.write a NumPy program to compute the sum of the diagonal element of a given array(matrix).

# %%
t=s.outer(p,q)
print(s.trace(t))
# Out:
# 5
